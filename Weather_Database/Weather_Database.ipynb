# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 792

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Import the OpenWeatherMap's API key
from config_2 import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8fec6fe55dd993c7d09ae4d55b377133

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | burns lake
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | henties bay
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | sahrak
# City not found. Skipping...
# Processing Record 7 of Set 1 | tamiahua
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | acarau
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | namibe
# Processing Record 13 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | samsun
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | mount gambier
# Processing Record 24 of Set 1 | snezhnogorsk
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | areia branca
# Processing Record 27 of Set 1 | kruisfontein
# Processing Record 28 of Set 1 | faanui
# Processing Record 29 of Set 1 | hualmay
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | bera
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | port hawkesbury
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | ancud
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | nhulunbuy
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | fortuna
# Processing Record 48 of Set 1 | tuatapere
# Processing Record 49 of Set 1 | rawson
# Processing Record 50 of Set 1 | gillette
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | erzin
# Processing Record 4 of Set 2 | sao filipe
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | laguna
# Processing Record 8 of Set 2 | mayya
# Processing Record 9 of Set 2 | ketchikan
# Processing Record 10 of Set 2 | enshi
# Processing Record 11 of Set 2 | nuuk
# Processing Record 12 of Set 2 | taft
# Processing Record 13 of Set 2 | kerema
# Processing Record 14 of Set 2 | akureyri
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | remanso
# Processing Record 18 of Set 2 | rio grande
# Processing Record 19 of Set 2 | lorengau
# Processing Record 20 of Set 2 | helong
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | at-bashi
# Processing Record 23 of Set 2 | aloleng
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | biu
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 2 | diego de almagro
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | klaksvik
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | sobolevo
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | sept-iles
# Processing Record 35 of Set 2 | cockburn town
# Processing Record 36 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 2 | ayaviri
# Processing Record 40 of Set 2 | korla
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | bogotol
# Processing Record 43 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 44 of Set 2 | luena
# Processing Record 45 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 2 | cayenne
# Processing Record 47 of Set 2 | pangody
# Processing Record 48 of Set 2 | jawhar
# Processing Record 49 of Set 2 | kisangani
# Processing Record 50 of Set 2 | port hedland
# Processing Record 1 of Set 3 | victoria
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | samfya
# Processing Record 4 of Set 3 | comodoro rivadavia
# Processing Record 5 of Set 3 | isangel
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | bubaque
# Processing Record 8 of Set 3 | cape town
# Processing Record 9 of Set 3 | sorland
# Processing Record 10 of Set 3 | andros town
# Processing Record 11 of Set 3 | taoudenni
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | mapiripan
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | iqaluit
# Processing Record 17 of Set 3 | saint-augustin
# Processing Record 18 of Set 3 | san cristobal
# Processing Record 19 of Set 3 | vaitape
# Processing Record 20 of Set 3 | cairo
# Processing Record 21 of Set 3 | manzanillo
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | myrtle beach
# Processing Record 25 of Set 3 | havelock
# Processing Record 26 of Set 3 | husavik
# Processing Record 27 of Set 3 | rock sound
# Processing Record 28 of Set 3 | chuy
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | hofn
# Processing Record 31 of Set 3 | talnakh
# Processing Record 32 of Set 3 | faya
# Processing Record 33 of Set 3 | ames
# Processing Record 34 of Set 3 | calvinia
# Processing Record 35 of Set 3 | oriximina
# Processing Record 36 of Set 3 | khasan
# Processing Record 37 of Set 3 | novotalitsy
# City not found. Skipping...
# Processing Record 38 of Set 3 | oistins
# Processing Record 39 of Set 3 | mabaruma
# Processing Record 40 of Set 3 | stony plain
# Processing Record 41 of Set 3 | aviles
# Processing Record 42 of Set 3 | merke
# Processing Record 43 of Set 3 | kenora
# Processing Record 44 of Set 3 | panaba
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | balkhash
# Processing Record 47 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | gezing
# Processing Record 50 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 4 | nesbyen
# Processing Record 2 of Set 4 | atar
# Processing Record 3 of Set 4 | san martin
# Processing Record 4 of Set 4 | hazorasp
# Processing Record 5 of Set 4 | luwuk
# Processing Record 6 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 4 | brunswick
# Processing Record 8 of Set 4 | usevya
# Processing Record 9 of Set 4 | alice springs
# Processing Record 10 of Set 4 | port-gentil
# Processing Record 11 of Set 4 | cabedelo
# Processing Record 12 of Set 4 | bonga
# Processing Record 13 of Set 4 | hay river
# Processing Record 14 of Set 4 | geraldton
# Processing Record 15 of Set 4 | beloha
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | la libertad
# Processing Record 18 of Set 4 | kutum
# Processing Record 19 of Set 4 | san quintin
# Processing Record 20 of Set 4 | salinopolis
# Processing Record 21 of Set 4 | itoman
# Processing Record 22 of Set 4 | dakar
# Processing Record 23 of Set 4 | mount isa
# Processing Record 24 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 4 | batemans bay
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | robertsport
# Processing Record 28 of Set 4 | camacha
# Processing Record 29 of Set 4 | port shepstone
# Processing Record 30 of Set 4 | copala
# Processing Record 31 of Set 4 | nanortalik
# Processing Record 32 of Set 4 | misratah
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | hami
# Processing Record 35 of Set 4 | fairbanks
# Processing Record 36 of Set 4 | heihe
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | kyra
# Processing Record 39 of Set 4 | yaan
# Processing Record 40 of Set 4 | plano
# Processing Record 41 of Set 4 | terra nova
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | honningsvag
# Processing Record 44 of Set 4 | puerto leguizamo
# Processing Record 45 of Set 4 | wajir
# Processing Record 46 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 4 | port said
# Processing Record 48 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 49 of Set 4 | keti bandar
# Processing Record 50 of Set 4 | pochutla
# Processing Record 1 of Set 5 | nemuro
# Processing Record 2 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 3 of Set 5 | ishigaki
# Processing Record 4 of Set 5 | gilbues
# Processing Record 5 of Set 5 | boone
# Processing Record 6 of Set 5 | paita
# Processing Record 7 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 5 | narsaq
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 5 | mehamn
# Processing Record 12 of Set 5 | neuquen
# Processing Record 13 of Set 5 | tuktoyaktuk
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 5 | iwanai
# Processing Record 17 of Set 5 | eskisehir
# Processing Record 18 of Set 5 | kurilsk
# Processing Record 19 of Set 5 | bismarck
# Processing Record 20 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | liminangcong
# City not found. Skipping...
# Processing Record 22 of Set 5 | livingston
# Processing Record 23 of Set 5 | college
# Processing Record 24 of Set 5 | georgetown
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | coquimbo
# Processing Record 27 of Set 5 | maku
# Processing Record 28 of Set 5 | boguchany
# Processing Record 29 of Set 5 | kyzyl-suu
# Processing Record 30 of Set 5 | bac lieu
# Processing Record 31 of Set 5 | naze
# Processing Record 32 of Set 5 | okakarara
# Processing Record 33 of Set 5 | whitecourt
# Processing Record 34 of Set 5 | kizukuri
# Processing Record 35 of Set 5 | esperance
# Processing Record 36 of Set 5 | road town
# Processing Record 37 of Set 5 | kon tum
# Processing Record 38 of Set 5 | olinda
# Processing Record 39 of Set 5 | faratsiho
# Processing Record 40 of Set 5 | arimalam
# Processing Record 41 of Set 5 | jiangyou
# Processing Record 42 of Set 5 | gamba
# Processing Record 43 of Set 5 | santiago del estero
# Processing Record 44 of Set 5 | skjervoy
# Processing Record 45 of Set 5 | lyngseidet
# Processing Record 46 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 5 | hede
# Processing Record 48 of Set 5 | tautira
# Processing Record 49 of Set 5 | katsuura
# Processing Record 50 of Set 5 | warrington
# Processing Record 1 of Set 6 | bonoua
# Processing Record 2 of Set 6 | kavieng
# Processing Record 3 of Set 6 | tawzar
# City not found. Skipping...
# Processing Record 4 of Set 6 | bela
# Processing Record 5 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 6 | kiunga
# Processing Record 7 of Set 6 | wiarton
# Processing Record 8 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 9 of Set 6 | liverpool
# Processing Record 10 of Set 6 | tasiilaq
# Processing Record 11 of Set 6 | saint-pierre
# Processing Record 12 of Set 6 | burgeo
# Processing Record 13 of Set 6 | swan hill
# Processing Record 14 of Set 6 | pangnirtung
# Processing Record 15 of Set 6 | moscow
# Processing Record 16 of Set 6 | constitucion
# Processing Record 17 of Set 6 | raipur
# Processing Record 18 of Set 6 | bagan
# Processing Record 19 of Set 6 | kavaratti
# Processing Record 20 of Set 6 | bethel
# Processing Record 21 of Set 6 | kodiak
# Processing Record 22 of Set 6 | palmer
# Processing Record 23 of Set 6 | zhigansk
# Processing Record 24 of Set 6 | solnechnyy
# Processing Record 25 of Set 6 | ranot
# Processing Record 26 of Set 6 | svetlogorsk
# Processing Record 27 of Set 6 | merrill
# Processing Record 28 of Set 6 | waukesha
# Processing Record 29 of Set 6 | clyde river
# Processing Record 30 of Set 6 | prince rupert
# Processing Record 31 of Set 6 | ouidah
# Processing Record 32 of Set 6 | kahului
# Processing Record 33 of Set 6 | qandala
# Processing Record 34 of Set 6 | vestmanna
# Processing Record 35 of Set 6 | kinkala
# Processing Record 36 of Set 6 | oum hadjer
# Processing Record 37 of Set 6 | cabo san lucas
# Processing Record 38 of Set 6 | trondheim
# Processing Record 39 of Set 6 | trairi
# Processing Record 40 of Set 6 | hof
# Processing Record 41 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 6 | sergeyevka
# Processing Record 43 of Set 6 | saint george
# Processing Record 44 of Set 6 | vostok
# Processing Record 45 of Set 6 | russell
# Processing Record 46 of Set 6 | hobyo
# Processing Record 47 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 48 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 6 | havre-saint-pierre
# Processing Record 50 of Set 6 | xunchang
# Processing Record 1 of Set 7 | lundazi
# Processing Record 2 of Set 7 | burlington
# Processing Record 3 of Set 7 | sisimiut
# Processing Record 4 of Set 7 | kalmunai
# Processing Record 5 of Set 7 | phalaborwa
# Processing Record 6 of Set 7 | adrar
# Processing Record 7 of Set 7 | akonolinga
# Processing Record 8 of Set 7 | xuddur
# Processing Record 9 of Set 7 | tazmalt
# Processing Record 10 of Set 7 | kinshasa
# Processing Record 11 of Set 7 | hasaki
# Processing Record 12 of Set 7 | afsin
# Processing Record 13 of Set 7 | sterling
# Processing Record 14 of Set 7 | codrington
# Processing Record 15 of Set 7 | tucuman
# Processing Record 16 of Set 7 | slave lake
# Processing Record 17 of Set 7 | nimaparha
# Processing Record 18 of Set 7 | imbituba
# Processing Record 19 of Set 7 | kozhva
# Processing Record 20 of Set 7 | komsomolskiy
# Processing Record 21 of Set 7 | colesberg
# Processing Record 22 of Set 7 | igurubi
# Processing Record 23 of Set 7 | port augusta
# Processing Record 24 of Set 7 | maryborough
# Processing Record 25 of Set 7 | maldonado
# Processing Record 26 of Set 7 | the pas
# Processing Record 27 of Set 7 | piracanjuba
# Processing Record 28 of Set 7 | lasa
# Processing Record 29 of Set 7 | mashhad
# Processing Record 30 of Set 7 | terra santa
# Processing Record 31 of Set 7 | bardiyah
# Processing Record 32 of Set 7 | puerto quijarro
# Processing Record 33 of Set 7 | puerto varas
# Processing Record 34 of Set 7 | tommot
# Processing Record 35 of Set 7 | pisco
# Processing Record 36 of Set 7 | dongsheng
# Processing Record 37 of Set 7 | tatawin
# Processing Record 38 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 7 | viedma
# Processing Record 40 of Set 7 | haines junction
# Processing Record 41 of Set 7 | batsfjord
# Processing Record 42 of Set 7 | lingyuan
# Processing Record 43 of Set 7 | asau
# Processing Record 44 of Set 7 | zaragoza
# Processing Record 45 of Set 7 | jennings
# Processing Record 46 of Set 7 | katobu
# Processing Record 47 of Set 7 | arlit
# Processing Record 48 of Set 7 | souillac
# Processing Record 49 of Set 7 | starozhilovo
# Processing Record 50 of Set 7 | kursenai
# Processing Record 1 of Set 8 | vila do maio
# Processing Record 2 of Set 8 | moose factory
# Processing Record 3 of Set 8 | kumluca
# Processing Record 4 of Set 8 | coxim
# Processing Record 5 of Set 8 | guerrero negro
# Processing Record 6 of Set 8 | parkes
# Processing Record 7 of Set 8 | vila franca do campo
# Processing Record 8 of Set 8 | karakol
# Processing Record 9 of Set 8 | haileybury
# Processing Record 10 of Set 8 | hambantota
# Processing Record 11 of Set 8 | manta
# Processing Record 12 of Set 8 | arcata
# Processing Record 13 of Set 8 | llanes
# Processing Record 14 of Set 8 | portobelo
# Processing Record 15 of Set 8 | migori
# Processing Record 16 of Set 8 | talara
# Processing Record 17 of Set 8 | apiai
# Processing Record 18 of Set 8 | aktash
# Processing Record 19 of Set 8 | okha
# Processing Record 20 of Set 8 | tiarei
# Processing Record 21 of Set 8 | saldanha
# Processing Record 22 of Set 8 | coihaique
# Processing Record 23 of Set 8 | torbay
# Processing Record 24 of Set 8 | sapa
# Processing Record 25 of Set 8 | masinigudi
# Processing Record 26 of Set 8 | biltine
# Processing Record 27 of Set 8 | moerai
# Processing Record 28 of Set 8 | sur
# Processing Record 29 of Set 8 | sambava
# Processing Record 30 of Set 8 | baykit
# Processing Record 31 of Set 8 | romitan
# Processing Record 32 of Set 8 | sistranda
# Processing Record 33 of Set 8 | mugur-aksy
# Processing Record 34 of Set 8 | leh
# Processing Record 35 of Set 8 | noyabrsk
# Processing Record 36 of Set 8 | douentza
# Processing Record 37 of Set 8 | yamada
# Processing Record 38 of Set 8 | ribeira grande
# Processing Record 39 of Set 8 | praya
# Processing Record 40 of Set 8 | ayan
# Processing Record 41 of Set 8 | normandin
# Processing Record 42 of Set 8 | leningradskiy
# Processing Record 43 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 8 | shelburne
# Processing Record 45 of Set 8 | shakawe
# Processing Record 46 of Set 8 | necochea
# Processing Record 47 of Set 8 | celestun
# Processing Record 48 of Set 8 | mihalt
# Processing Record 49 of Set 8 | nara
# Processing Record 50 of Set 8 | mazagao
# Processing Record 1 of Set 9 | bisho
# Processing Record 2 of Set 9 | katoro
# Processing Record 3 of Set 9 | kaitangata
# Processing Record 4 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 9 | deputatskiy
# Processing Record 6 of Set 9 | skelleftea
# Processing Record 7 of Set 9 | sao joao da barra
# Processing Record 8 of Set 9 | stornoway
# Processing Record 9 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 9 | meulaboh
# Processing Record 11 of Set 9 | solotcha
# Processing Record 12 of Set 9 | saskylakh
# Processing Record 13 of Set 9 | gisborne
# Processing Record 14 of Set 9 | peachtree city
# Processing Record 15 of Set 9 | atasu
# Processing Record 16 of Set 9 | igarka
# Processing Record 17 of Set 9 | san carlos de bariloche
# Processing Record 18 of Set 9 | zhuhai
# Processing Record 19 of Set 9 | jaguaquara
# Processing Record 20 of Set 9 | lubango
# Processing Record 21 of Set 9 | rocha
# Processing Record 22 of Set 9 | lachute
# Processing Record 23 of Set 9 | poum
# Processing Record 24 of Set 9 | wiang sa
# Processing Record 25 of Set 9 | thanh hoa
# Processing Record 26 of Set 9 | newport
# Processing Record 27 of Set 9 | xinmin
# Processing Record 28 of Set 9 | indianola
# Processing Record 29 of Set 9 | makakilo city
# Processing Record 30 of Set 9 | koksovyy
# Processing Record 31 of Set 9 | tulum
# Processing Record 32 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 33 of Set 9 | puerto maldonado
# Processing Record 34 of Set 9 | balikpapan
# Processing Record 35 of Set 9 | la ronge
# Processing Record 36 of Set 9 | parabel
# Processing Record 37 of Set 9 | kununurra
# Processing Record 38 of Set 9 | valenca do piaui
# Processing Record 39 of Set 9 | fereydun kenar
# Processing Record 40 of Set 9 | buala
# Processing Record 41 of Set 9 | ardatov
# Processing Record 42 of Set 9 | san andres
# Processing Record 43 of Set 9 | tual
# Processing Record 44 of Set 9 | longyearbyen
# Processing Record 45 of Set 9 | antalaha
# Processing Record 46 of Set 9 | hervey bay
# Processing Record 47 of Set 9 | noumea
# Processing Record 48 of Set 9 | praia
# Processing Record 49 of Set 9 | australind
# Processing Record 50 of Set 9 | aklavik
# Processing Record 1 of Set 10 | yanam
# Processing Record 2 of Set 10 | thinadhoo
# Processing Record 3 of Set 10 | yulara
# Processing Record 4 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 10 | labuhan
# Processing Record 6 of Set 10 | kampot
# Processing Record 7 of Set 10 | beyneu
# Processing Record 8 of Set 10 | umm kaddadah
# Processing Record 9 of Set 10 | sain alto
# Processing Record 10 of Set 10 | lithakia
# Processing Record 11 of Set 10 | lipetsk
# Processing Record 12 of Set 10 | peniche
# Processing Record 13 of Set 10 | itaquyry
# Processing Record 14 of Set 10 | bayji
# Processing Record 15 of Set 10 | pontes e lacerda
# Processing Record 16 of Set 10 | sangre grande
# Processing Record 17 of Set 10 | axim
# Processing Record 18 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 19 of Set 10 | akyab
# Processing Record 20 of Set 10 | mingshui
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | nioaque
# Processing Record 23 of Set 10 | tshela
# Processing Record 24 of Set 10 | egvekinot
# Processing Record 25 of Set 10 | ulladulla
# Processing Record 26 of Set 10 | ilulissat
# Processing Record 27 of Set 10 | alofi
# Processing Record 28 of Set 10 | belene
# Processing Record 29 of Set 10 | abnub
# Processing Record 30 of Set 10 | cam ranh
# Processing Record 31 of Set 10 | umarkhed
# Processing Record 32 of Set 10 | turukhansk
# Processing Record 33 of Set 10 | portland
# Processing Record 34 of Set 10 | san rafael
# Processing Record 35 of Set 10 | matagami
# Processing Record 36 of Set 10 | tiksi
# Processing Record 37 of Set 10 | westlock
# Processing Record 38 of Set 10 | bilma
# Processing Record 39 of Set 10 | te anau
# Processing Record 40 of Set 10 | tall kayf
# Processing Record 41 of Set 10 | tabou
# Processing Record 42 of Set 10 | muros
# Processing Record 43 of Set 10 | clarksville
# Processing Record 44 of Set 10 | nisia floresta
# Processing Record 45 of Set 10 | flinders
# Processing Record 46 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 47 of Set 10 | gat
# Processing Record 48 of Set 10 | altagracia de orituco
# Processing Record 49 of Set 10 | usakos
# Processing Record 50 of Set 10 | gagra
# Processing Record 1 of Set 11 | vizinga
# Processing Record 2 of Set 11 | floro
# Processing Record 3 of Set 11 | swellendam
# Processing Record 4 of Set 11 | cuauhtemoc
# Processing Record 5 of Set 11 | yuci
# Processing Record 6 of Set 11 | porto belo
# Processing Record 7 of Set 11 | abha
# Processing Record 8 of Set 11 | pinega
# Processing Record 9 of Set 11 | victoria point
# Processing Record 10 of Set 11 | anadyr
# Processing Record 11 of Set 11 | yei
# Processing Record 12 of Set 11 | great yarmouth
# Processing Record 13 of Set 11 | salalah
# Processing Record 14 of Set 11 | tafresh
# Processing Record 15 of Set 11 | guaxupe
# Processing Record 16 of Set 11 | nantucket
# Processing Record 17 of Set 11 | lagoa
# Processing Record 18 of Set 11 | vientiane
# Processing Record 19 of Set 11 | razole
# Processing Record 20 of Set 11 | pakxan
# Processing Record 21 of Set 11 | veszto
# Processing Record 22 of Set 11 | ossora
# Processing Record 23 of Set 11 | kiama
# Processing Record 24 of Set 11 | porto novo
# Processing Record 25 of Set 11 | ucluelet
# Processing Record 26 of Set 11 | lokosovo
# Processing Record 27 of Set 11 | port blair
# Processing Record 28 of Set 11 | caravelas
# Processing Record 29 of Set 11 | guanay
# Processing Record 30 of Set 11 | genhe
# Processing Record 31 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 11 | harper
# Processing Record 33 of Set 11 | brae
# Processing Record 34 of Set 11 | high level
# Processing Record 35 of Set 11 | acapulco
# Processing Record 36 of Set 11 | tateyama
# Processing Record 37 of Set 11 | qiongshan
# Processing Record 38 of Set 11 | sukumo
# Processing Record 39 of Set 11 | jalu
# Processing Record 40 of Set 11 | bani walid
# Processing Record 41 of Set 11 | whitehorse
# Processing Record 42 of Set 11 | kirakira
# Processing Record 43 of Set 11 | bam
# Processing Record 44 of Set 11 | barra do garcas
# Processing Record 45 of Set 11 | brenham
# Processing Record 46 of Set 11 | vardo
# Processing Record 47 of Set 11 | inhambane
# Processing Record 48 of Set 11 | kovernino
# Processing Record 49 of Set 11 | nador
# Processing Record 50 of Set 11 | sembakung
# Processing Record 1 of Set 12 | chokurdakh
# Processing Record 2 of Set 12 | la sarre
# Processing Record 3 of Set 12 | fez
# Processing Record 4 of Set 12 | alakurtti
# Processing Record 5 of Set 12 | sabha
# Processing Record 6 of Set 12 | altay
# Processing Record 7 of Set 12 | mehriz
# Processing Record 8 of Set 12 | trois-rivieres
# Processing Record 9 of Set 12 | waingapu
# Processing Record 10 of Set 12 | kasongo-lunda
# Processing Record 11 of Set 12 | aginskoye
# Processing Record 12 of Set 12 | marystown
# Processing Record 13 of Set 12 | kariapatti
# Processing Record 14 of Set 12 | abbeville
# Processing Record 15 of Set 12 | chapais
# Processing Record 16 of Set 12 | sibolga
# Processing Record 17 of Set 12 | butembo
# Processing Record 18 of Set 12 | amarante
# Processing Record 19 of Set 12 | wawa
# Processing Record 20 of Set 12 | grand gaube
# Processing Record 21 of Set 12 | guilford
# Processing Record 22 of Set 12 | pacific grove
# Processing Record 23 of Set 12 | cherskiy
# Processing Record 24 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 12 | margate
# Processing Record 26 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 27 of Set 12 | ust-kulom
# Processing Record 28 of Set 12 | norsup
# Processing Record 29 of Set 12 | leshan
# Processing Record 30 of Set 12 | okhotsk
# Processing Record 31 of Set 12 | abdanan
# Processing Record 32 of Set 12 | chachapoyas
# Processing Record 33 of Set 12 | trincomalee
# Processing Record 34 of Set 12 | farafangana
# Processing Record 35 of Set 12 | kieta
# Processing Record 36 of Set 12 | bindura
# Processing Record 37 of Set 12 | kamiiso
# Processing Record 38 of Set 12 | grenville
# Processing Record 39 of Set 12 | kalach-na-donu
# Processing Record 40 of Set 12 | the valley
# Processing Record 41 of Set 12 | byron bay
# Processing Record 42 of Set 12 | qui nhon
# Processing Record 43 of Set 12 | krasnaya gora
# Processing Record 44 of Set 12 | miandrivazo
# Processing Record 45 of Set 12 | george town
# Processing Record 46 of Set 12 | metro
# Processing Record 47 of Set 12 | oranjemund
# Processing Record 48 of Set 12 | bandarbeyla
# Processing Record 49 of Set 12 | kajaani
# Processing Record 50 of Set 12 | monduli
# Processing Record 1 of Set 13 | pedernales
# Processing Record 2 of Set 13 | ebeltoft
# Processing Record 3 of Set 13 | flin flon
# Processing Record 4 of Set 13 | brazzaville
# Processing Record 5 of Set 13 | novyye lyady
# Processing Record 6 of Set 13 | tilichiki
# Processing Record 7 of Set 13 | vao
# Processing Record 8 of Set 13 | khandyga
# Processing Record 9 of Set 13 | rovenki
# Processing Record 10 of Set 13 | yar-sale
# Processing Record 11 of Set 13 | kolokani
# Processing Record 12 of Set 13 | luorong
# Processing Record 13 of Set 13 | tubuala
# Processing Record 14 of Set 13 | carahue
# Processing Record 15 of Set 13 | karratha
# Processing Record 16 of Set 13 | kotido
# Processing Record 17 of Set 13 | vila velha
# Processing Record 18 of Set 13 | qax
# Processing Record 19 of Set 13 | agapovka
# Processing Record 20 of Set 13 | zabol
# Processing Record 21 of Set 13 | baturaja
# Processing Record 22 of Set 13 | saint-malo
# Processing Record 23 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 24 of Set 13 | shingu
# Processing Record 25 of Set 13 | banda aceh
# Processing Record 26 of Set 13 | banska bystrica
# Processing Record 27 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 13 | seoul
# Processing Record 29 of Set 13 | velikie luki
# City not found. Skipping...
# Processing Record 30 of Set 13 | izumo
# Processing Record 31 of Set 13 | oktyabrskoye
# Processing Record 32 of Set 13 | lavrentiya
# Processing Record 33 of Set 13 | dickson
# Processing Record 34 of Set 13 | opuwo
# Processing Record 35 of Set 13 | sangar
# Processing Record 36 of Set 13 | dunedin
# Processing Record 37 of Set 13 | zyryanka
# Processing Record 38 of Set 13 | dzaoudzi
# Processing Record 39 of Set 13 | arcachon
# Processing Record 40 of Set 13 | amurzet
# Processing Record 41 of Set 13 | itaituba
# Processing Record 42 of Set 13 | bahia blanca
# Processing Record 43 of Set 13 | tombouctou
# Processing Record 44 of Set 13 | coahuayana
# Processing Record 45 of Set 13 | poplar bluff
# Processing Record 46 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 13 | bengkulu
# Processing Record 48 of Set 13 | manitouwadge
# Processing Record 49 of Set 13 | imuris
# Processing Record 50 of Set 13 | cabadiangan
# Processing Record 1 of Set 14 | innisfail
# Processing Record 2 of Set 14 | beira
# Processing Record 3 of Set 14 | camana
# Processing Record 4 of Set 14 | baruun-urt
# Processing Record 5 of Set 14 | lotofaga
# Processing Record 6 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 7 of Set 14 | makat
# Processing Record 8 of Set 14 | sehithwa
# Processing Record 9 of Set 14 | valle de allende
# Processing Record 10 of Set 14 | tornio
# Processing Record 11 of Set 14 | araouane
# Processing Record 12 of Set 14 | uk
# City not found. Skipping...
# Processing Record 13 of Set 14 | old road
# City not found. Skipping...
# Processing Record 14 of Set 14 | krasnoselkup
# Processing Record 15 of Set 14 | sibu
# Processing Record 16 of Set 14 | malmesbury
# Processing Record 17 of Set 14 | kenai
# Processing Record 18 of Set 14 | luderitz
# Processing Record 19 of Set 14 | maceio
# Processing Record 20 of Set 14 | emerald
# Processing Record 21 of Set 14 | muroto
# Processing Record 22 of Set 14 | boa vista
# Processing Record 23 of Set 14 | umkomaas
# Processing Record 24 of Set 14 | de-kastri
# Processing Record 25 of Set 14 | saint-georges
# Processing Record 26 of Set 14 | montague
# Processing Record 27 of Set 14 | sars
# Processing Record 28 of Set 14 | zruc nad sazavou
# Processing Record 29 of Set 14 | biak
# Processing Record 30 of Set 14 | kulhudhuffushi
# Processing Record 31 of Set 14 | athabasca
# Processing Record 32 of Set 14 | churapcha
# Processing Record 33 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 14 | gulbene
# Processing Record 35 of Set 14 | vila
# Processing Record 36 of Set 14 | namatanai
# Processing Record 37 of Set 14 | dudinka
# Processing Record 38 of Set 14 | itarema
# Processing Record 39 of Set 14 | ambon
# Processing Record 40 of Set 14 | caraballeda
# Processing Record 41 of Set 14 | takoradi
# Processing Record 42 of Set 14 | bolobo
# Processing Record 43 of Set 14 | kuching
# Processing Record 44 of Set 14 | buenos aires
# Processing Record 45 of Set 14 | kokopo
# Processing Record 46 of Set 14 | nelson
# Processing Record 47 of Set 14 | kiknur
# Processing Record 48 of Set 14 | ballina
# Processing Record 49 of Set 14 | thunder bay
# Processing Record 50 of Set 14 | saint anthony
# Processing Record 1 of Set 15 | beringovskiy
# Processing Record 2 of Set 15 | dalby
# Processing Record 3 of Set 15 | aswan
# Processing Record 4 of Set 15 | semey
# Processing Record 5 of Set 15 | sturgeon falls
# Processing Record 6 of Set 15 | lerwick
# Processing Record 7 of Set 15 | ust-kan
# Processing Record 8 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 15 | buchanan
# Processing Record 10 of Set 15 | bonthe
# Processing Record 11 of Set 15 | lovozero
# Processing Record 12 of Set 15 | slobidka
# Processing Record 13 of Set 15 | gondanglegi
# Processing Record 14 of Set 15 | paracuru
# Processing Record 15 of Set 15 | osorno
# Processing Record 16 of Set 15 | culasi
# Processing Record 17 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 18 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 15 | loiza
# Processing Record 20 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 15 | manokwari
# Processing Record 22 of Set 15 | fukue
# Processing Record 23 of Set 15 | piacabucu
# Processing Record 24 of Set 15 | ahuimanu
# Processing Record 25 of Set 15 | anaconda
# Processing Record 26 of Set 15 | pringsewu
# Processing Record 27 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 28 of Set 15 | mazamari
# Processing Record 29 of Set 15 | najran
# Processing Record 30 of Set 15 | vavozh
# Processing Record 31 of Set 15 | kindu
# Processing Record 32 of Set 15 | oktyabrskiy
# Processing Record 33 of Set 15 | sola
# Processing Record 34 of Set 15 | magistralnyy
# Processing Record 35 of Set 15 | padang
# Processing Record 36 of Set 15 | nacala
# Processing Record 37 of Set 15 | aksarka
# Processing Record 38 of Set 15 | staryy nadym
# Processing Record 39 of Set 15 | camopi
# Processing Record 40 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 41 of Set 15 | rybachiy
# Processing Record 42 of Set 15 | sao gabriel da cachoeira
# Processing Record 43 of Set 15 | kitovo
# Processing Record 44 of Set 15 | kalemie
# Processing Record 45 of Set 15 | beitbridge
# Processing Record 46 of Set 15 | anzio
# Processing Record 47 of Set 15 | chicama
# Processing Record 48 of Set 15 | channel-port aux basques
# Processing Record 49 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 15 | tevriz
# Processing Record 1 of Set 16 | erenhot
# Processing Record 2 of Set 16 | selenginsk
# Processing Record 3 of Set 16 | kibre mengist
# Processing Record 4 of Set 16 | bairiki
# Processing Record 5 of Set 16 | ostrovnoy
# Processing Record 6 of Set 16 | abeche
# Processing Record 7 of Set 16 | alibag
# Processing Record 8 of Set 16 | smithers
# Processing Record 9 of Set 16 | kitaibaraki
# Processing Record 10 of Set 16 | bayir
# Processing Record 11 of Set 16 | bolshaya rechka
# Processing Record 12 of Set 16 | pathein
# Processing Record 13 of Set 16 | nouadhibou
# Processing Record 14 of Set 16 | iberia
# Processing Record 15 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 16 | zhezkazgan
# Processing Record 17 of Set 16 | esmeraldas
# Processing Record 18 of Set 16 | mocuba
# Processing Record 19 of Set 16 | grindavik
# Processing Record 20 of Set 16 | liku
# Processing Record 21 of Set 16 | halifax
# Processing Record 22 of Set 16 | nautla
# Processing Record 23 of Set 16 | strezhevoy
# Processing Record 24 of Set 16 | ukiah
# Processing Record 25 of Set 16 | givors
# Processing Record 26 of Set 16 | stanger
# Processing Record 27 of Set 16 | farmington
# Processing Record 28 of Set 16 | sokoni
# Processing Record 29 of Set 16 | conceicao da barra
# Processing Record 30 of Set 16 | gboko
# Processing Record 31 of Set 16 | lake charles
# Processing Record 32 of Set 16 | broken hill
# Processing Record 33 of Set 16 | port lincoln
# Processing Record 34 of Set 16 | pentecoste
# Processing Record 35 of Set 16 | begunitsy
# Processing Record 36 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 16 | pauini
# Processing Record 38 of Set 16 | turan
# Processing Record 39 of Set 16 | krylovskaya
# Processing Record 40 of Set 16 | flers
# Processing Record 41 of Set 16 | raudeberg
# Processing Record 42 of Set 16 | buzmeyin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 729

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Burns Lake  54.2331 -125.7533     22.82        77         100        3.74
# 1    Hithadhoo  -0.6000   73.0833     81.21        75         100       15.39
# 2  Henties Bay -22.1160   14.2845     56.93        87          31        5.50
# 3    Upernavik  72.7868  -56.1549     14.85        50          30        4.59
# 4     Tamiahua  21.2667  -97.4500     74.34        89          10        2.24
# 5       Hobart -42.8794  147.3294     62.46        42          40       23.02
# 6        Kapaa  22.0752 -159.3190     79.12        86          75       12.66
# 7       Acarau  -2.8856  -40.1200     77.00        85          32        7.94
# 8       Albany  42.6001  -73.9662     47.73        74          23        1.43
# 9       Namibe -15.1961   12.1522     67.59        80          39        2.62
#
#   Country                 Date
# 0      CA  2022-11-03 05:04:24
# 1      MV  2022-11-03 05:04:25
# 2      NA  2022-11-03 05:04:25
# 3      GL  2022-11-03 05:04:25
# 4      MX  2022-11-03 05:04:26
# 5      AU  2022-11-03 05:02:08
# 6      US  2022-11-03 05:04:26
# 7      BR  2022-11-03 05:04:27
# 8      US  2022-11-03 05:00:20
# 9      AO  2022-11-03 05:03:36

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Burns Lake      CA  54.2331 -125.7533     22.82        77         100
# 1    Hithadhoo      MV  -0.6000   73.0833     81.21        75         100
# 2  Henties Bay      NA -22.1160   14.2845     56.93        87          31
# 3    Upernavik      GL  72.7868  -56.1549     14.85        50          30
# 4     Tamiahua      MX  21.2667  -97.4500     74.34        89          10
# 5       Hobart      AU -42.8794  147.3294     62.46        42          40
# 6        Kapaa      US  22.0752 -159.3190     79.12        86          75
# 7       Acarau      BR  -2.8856  -40.1200     77.00        85          32
# 8       Albany      US  42.6001  -73.9662     47.73        74          23
# 9       Namibe      AO -15.1961   12.1522     67.59        80          39
#
#    Wind Speed
# 0        3.74
# 1       15.39
# 2        5.50
# 3        4.59
# 4        2.24
# 5       23.02
# 6       12.66
# 7        7.94
# 8        1.43
# 9        2.62

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
